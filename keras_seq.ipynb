# %%
import tensorflow as tf
import sklearn as sk
from sklearn import preprocessing
import pandas as pd

# %%
df = pd.read_csv('3.csv')

# %%
df.head()
# Out:
#    TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0         74        60        45           67.0          49.0          43.0
# 1         56        48        39           43.0          36.0          28.0
# 2         58        45        32           31.0          27.0          23.0
# 3         61        46        31           36.0          28.0          21.0
# 4         58        50        41           44.0          40.0          36.0
#
#    HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0                 93.0                75.0                57.0
# 1                 93.0                68.0                43.0
# 2                 76.0                52.0                27.0
# 3                 89.0                56.0                22.0
# 4                 86.0                71.0                56.0
#
#    SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                       29.86                      29.68
# 1                       30.41                      30.13
# 2                       30.56                      30.49
# 3                       30.56                      30.45
# 4                       30.41                      30.33
#
#    SeaLevelPressureLowInches  VisibilityHighMiles  VisibilityAvgMiles  \
# 0                      29.59                 10.0                 7.0
# 1                      29.87                 10.0                10.0
# 2                      30.41                 10.0                10.0
# 3                      30.30                 10.0                10.0
# 4                      30.27                 10.0                10.0
#
#    VisibilityLowMiles  WindHighMPH  WindAvgMPH  WindGustMPH  \
# 0                 2.0           20           4           31
# 1                 5.0           16           6           25
# 2                10.0            8           3           12
# 3                 7.0           12           4           20
# 4                 7.0           10           2           16
#
#    PrecipitationSumInches
# 0                    0.46
# 1                    0.00
# 2                    0.00
# 3                    0.00
# 4                    0.00

# %%
x = df.drop(['PrecipitationSumInches'], axis=1)
y = df['PrecipitationSumInches']

# %%
n = 0.8
l = len(x)
print(l)
# Out:
# 335

# %%
train_x = x[0:int(n*l)]
train_y = y[0:int(n*l)]
val_x = x[int(n*l):]
val_y = y[int(n*l):]
print(train_x)
print(val_y)
# Out:
#      TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0           74        60        45           67.0          49.0          43.0
# 1           56        48        39           43.0          36.0          28.0
# 2           58        45        32           31.0          27.0          23.0
# 3           61        46        31           36.0          28.0          21.0
# 4           58        50        41           44.0          40.0          36.0
# ..         ...       ...       ...            ...           ...           ...
# 263         99        88        77           73.0          71.0          66.0
# 264         99        89        78           75.0          71.0          64.0
# 265         96        81        66           74.0          70.0          62.0
# 266         66        63        60           63.0          60.0          57.0
# 267         77        71        64           67.0          64.0          62.0
#
#      HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0                   93.0                75.0                57.0
# 1                   93.0                68.0                43.0
# 2                   76.0                52.0                27.0
# 3                   89.0                56.0                22.0
# 4                   86.0                71.0                56.0
# ..                   ...                 ...                 ...
# 263                 88.0                63.0                38.0
# 264                 85.0                60.0                35.0
# 265                 94.0                67.0                39.0
# 266                100.0                92.0                84.0
# 267                100.0                87.0                73.0
#
#      SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                         29.86                      29.68
# 1                         30.41                      30.13
# 2                         30.56                      30.49
# 3                         30.56                      30.45
# 4                         30.41                      30.33
# ..                          ...                        ...
# 263                       29.90                      29.83
# 264                       29.97                      29.89
# 265                       30.15                      30.00
# 266                       30.24                      30.19
# 267                       30.23                      30.16
#
#      SeaLevelPressureLowInches  VisibilityHighMiles  VisibilityAvgMiles  \
# 0                        29.59                 10.0                 7.0
# 1                        29.87                 10.0                10.0
# 2                        30.41                 10.0                10.0
# 3                        30.30                 10.0                10.0
# 4                        30.27                 10.0                10.0
# ..                         ...                  ...                 ...
# 263                      29.75                 10.0                10.0
# 264                      29.81                 10.0                10.0
# 265                      29.91                 10.0                 9.0
# 266                      30.10                 10.0                 5.0
# 267                      30.10                 10.0                 8.0
#
#      VisibilityLowMiles  WindHighMPH  WindAvgMPH  WindGustMPH
# 0                   2.0           20           4           31
# 1                   5.0           16           6           25
# 2                  10.0            8           3           12
# 3                   7.0           12           4           20
# 4                   7.0           10           2           16
# ..                  ...          ...         ...          ...
# 263                10.0           14           7           25
# 264                10.0           10           5           19
# 265                 1.0           15           5           24
# 266                 1.0           14           5           24
# 267                 3.0            7           2           10
#
# [268 rows x 18 columns]
# 268    0.00
# 269    0.02
# 270    0.35
# 271    3.66
# 272    0.13
#        ...
# 330    0.01
# 331    0.00
# 332    0.00
# 333    0.00
# 334    0.01
# Name: PrecipitationSumInches, Length: 67, dtype: float64
