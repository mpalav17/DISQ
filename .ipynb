# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Rainfall data for the year 2016.csv')
df = df.drop(['Date'], axis = 1)
df.head()
# Out:
#    TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0         74        60        45            67           49           43
# 1         56        48        39            43           36           28
# 2         58        45        32            31           27           23
# 3         61        46        31            36           28           21
# 4         58        50        41            44           40           36
#
#   HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                  93                 75                 57
# 1                  93                 68                 43
# 2                  76                 52                 27
# 3                  89                 56                 22
# 4                  86                 71                 56
#
#    SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                       29.86                      29.68
# ...

# %%
df = df.replace('T', 0.0)
df = df.replace('-', 0.0)
df.head()
# Out:
#    TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0         74        60        45            67           49           43
# 1         56        48        39            43           36           28
# 2         58        45        32            31           27           23
# 3         61        46        31            36           28           21
# 4         58        50        41            44           40           36
#
#   HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                  93                 75                 57
# 1                  93                 68                 43
# 2                  76                 52                 27
# 3                  89                 56                 22
# 4                  86                 71                 56
#
#    SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                       29.86                      29.68
# ...

# %%
print(df.values[0])
# Out:
# [74 60 45 '67' '49' '43' '93' '75' '57' 29.86 29.68 29.59 '10' '7' '2' 20
#  4 31 '0.46']

# %%
df.to_csv('1.csv', index = False)

# %%
for i in range(335,364):
    print(i, end=',')
# Out:
# 335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,

# %%
df = df.drop(df.index[[335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363]])
df.head()
# Out:
#    TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0         74        60        45            67           49           43
# 1         56        48        39            43           36           28
# 2         58        45        32            31           27           23
# 3         61        46        31            36           28           21
# 4         58        50        41            44           40           36
#
#   HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                  93                 75                 57
# 1                  93                 68                 43
# 2                  76                 52                 27
# 3                  89                 56                 22
# 4                  86                 71                 56
#
#    SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                       29.86                      29.68
# ...

# %%
print(df.values[0])
# Out:
# [74 60 45 '67' '49' '43' '93' '75' '57' 29.86 29.68 29.59 '10' '7' '2' 20
#  4 31 '0.46']

# %%
mm = df['PrecipitationSumInches']
mm = [float(i) * 25.4 for i in mm]

# %%
df = df.drop(['PrecipitationSumInches'], axis = 1)

# %%
df['Rainfallmm'] = mm
df.head()
# Out:
#    TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0         74        60        45            67           49           43
# 1         56        48        39            43           36           28
# 2         58        45        32            31           27           23
# 3         61        46        31            36           28           21
# 4         58        50        41            44           40           36
#
#   HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                  93                 75                 57
# 1                  93                 68                 43
# 2                  76                 52                 27
# 3                  89                 56                 22
# 4                  86                 71                 56
#
#    SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                       29.86                      29.68
# ...

# %%
df.head(20)
# Out:
#     TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0          74        60        45            67           49           43
# 1          56        48        39            43           36           28
# 2          58        45        32            31           27           23
# 3          61        46        31            36           28           21
# 4          58        50        41            44           40           36
# 5          57        48        39            39           36           33
# 6          60        53        45            41           39           37
# 7          62        51        40            43           39           33
# 8          64        50        36            49           41           28
# 9          44        40        35            31           26           21
# 10         55        46        36            31           28           23
# 11         69        54        39            51           42           30
# ...

# %%
print(df.values[0])
# Out:
# [74 60 45 '67' '49' '43' '93' '75' '57' 29.86 29.68 29.59 '10' '7' '2' 20
#  4 31 11.684]

# %%
df.to_csv('1.csv', index = False)

# %%
import sklearn as sk
from sklearn.linear_model import LinearRegression as LR

# %%
training_data = df.drop(['Rainfallmm'], axis = 1)
labels = df['Rainfallmm']

# %%
print(training_data.values[0])
# Out:
# [74 60 45 '67' '49' '43' '93' '75' '57' 29.86 29.68 29.59 '10' '7' '2' 20
#  4 31]

# %%
print(training_data)
# Out:
#      TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0           74        60        45            67           49           43
# 1           56        48        39            43           36           28
# 2           58        45        32            31           27           23
# 3           61        46        31            36           28           21
# 4           58        50        41            44           40           36
# ..         ...       ...       ...           ...          ...          ...
# 330         50        42        34            49           45           28
# 331         53        42        30            27           21           14
# 332         56        43        30            27           23           19
# 333         69        51        33            45           38           23
# 334         70        57        44            63           57           43
#
#     HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# ...

# %%
print(labels)
# Out:
# 0      11.684
# 1       0.000
# 2       0.000
# 3       0.000
# 4       0.000
#         ...
# 330     0.254
# 331     0.000
# 332     0.000
# 333     0.000
# 334     0.254
# Name: Rainfallmm, Length: 335, dtype: float64

# %%
model = LR()

# %%
model.fit(training_data, labels)
# Out:
# LinearRegression()

# %%
init_df = pd.read_csv('Rainfall data for the year 2016.csv')
init_df=init_df.drop(['Date', 'PrecipitationSumInches'], axis = 1)
init_df.head(337)
# Out:
#      TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0           74        60        45            67           49           43
# 1           56        48        39            43           36           28
# 2           58        45        32            31           27           23
# 3           61        46        31            36           28           21
# 4           58        50        41            44           40           36
# ..         ...       ...       ...           ...          ...          ...
# 332         56        43        30            27           23           19
# 333         69        51        33            45           38           23
# 334         70        57        44            63           57           43
# 335         74        68        62            69           65           62
# 336         67        63        58            64           62           56
#
#     HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# ...

# %%
init_df.to_csv('2.csv', index = False)

# %%
init_df = pd.read_csv('2.csv')
print(init_df.values[0])
# Out:
# [74 60 45 '67' '49' '43' '93' '75' '57' 29.86 29.68 29.59 '10' '7' '2' 20
#  4 31]

# %%
df1 = pd.read_csv('1.csv')
print(df1.values[0])
# Out:
# [74.    60.    45.    67.    49.    43.    93.    75.    57.    29.86
#  29.68  29.59  10.     7.     2.    20.     4.    31.    11.684]

# %%
print(init_df.values[157])
# Out:
# [73 68 63 '67' '64' '61' '93' '86' '79' 30.03 29.95 29.86 '10' '6' '0' 22
#  3 31]

# %%
inp = np.array([[74], [68], [62], [69], [65], [62], [100], [90], [79], [30.12], [30.05], [29.99], [10], [6], [0], [13], [5], [20]]) 
inp = inp.reshape(1, -1) 
print(model.predict(inp))
# Out:
# [12.9467503]

# %%
	Date	TempHighF	TempAvgF	TempLowF	DewPointHighF	DewPointAvgF	DewPointLowF	HumidityHighPercent	HumidityAvgPercent	HumidityLowPercent	SeaLevelPressureHighInches	SeaLevelPressureAvgInches	SeaLevelPressureLowInches	VisibilityHighMiles	VisibilityAvgMiles	VisibilityLowMiles	WindHighMPH	WindAvgMPH	WindGustMPH	PrecipitationSumInches	Events
1077	2016-12-01	69	53	37	43	34	31	85	56	27	30.16	30.08	30.01	10	10	10	12	3	16	0
