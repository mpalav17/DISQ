# %%
import pandas as pd
datedf = pd.read_csv('pre.csv')
datedf = datedf['Date'].drop(datedf.index[0:335])
datedf.to_csv('dates.csv', index=False)

# %%
predictdf = pd.read_csv('predicted.csv')
datedf = pd.read_csv('dates.csv')

# %%
predictdf.columns
# Out:
# Index(['Predictions'], dtype='object')

# %%
datedf = datedf.join(predictdf)
datedf.rename(columns = {'Predictions':'PredictedValues'}, inplace = True)
datedf
# Out:
#           Date  PredictedValues
# 0   01-12-2016        11.281964
# 1   02-12-2016        17.072787
# 2   03-12-2016         1.220412
# 3   04-12-2016         0.000000
# 4   05-12-2016         0.000000
# 5   06-12-2016         0.000000
# 6   07-12-2016         0.000000
# 7   08-12-2016         1.516794
# 8   09-12-2016         1.039765
# 9   10-12-2016         0.330468
# 10  11-12-2016         3.732159
# 11  12-12-2016         0.000000
# 12  13-12-2016         6.222200
# 13  14-12-2016        15.728601
# 14  15-12-2016         6.347876
# 15  16-12-2016         0.540755
# 16  17-12-2016         0.000000
# 17  18-12-2016         0.000000
# 18  19-12-2016         5.059248
# 19  20-12-2016         2.711136
# 20  21-12-2016         4.014792
# 21  22-12-2016         1.371837
# 22  23-12-2016         6.009098
# 23  24-12-2016         4.071699
# 24  25-12-2016         0.000000
# 25  26-12-2016         0.000000
# 26  27-12-2016         9.343730
# 27  28-12-2016        13.540066
# ...

# %%
datedf.to_csv('final_date_predictions.csv', index = False)
