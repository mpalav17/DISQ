# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('a.csv')
df
# Out:
#      TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0         74.0      60.0      45.0           67.0          49.0          43.0
# 1         56.0      48.0      39.0           43.0          36.0          28.0
# 2         58.0      45.0      32.0           31.0          27.0          23.0
# 3         61.0      46.0      31.0           36.0          28.0          21.0
# 4         58.0      50.0      41.0           44.0          40.0          36.0
# ..         ...       ...       ...            ...           ...           ...
# 329       48.0      44.0      40.0           47.0          39.0          23.0
# 330       50.0      42.0      34.0           49.0          45.0          28.0
# 331       53.0      42.0      30.0           27.0          21.0          14.0
# 332       56.0      43.0      30.0           27.0          23.0          19.0
# 333       69.0      51.0      33.0           45.0          38.0          23.0
#
# ...

# %%
plt.scatter(range(334),df['TempHighF'])
plt.scatter(range(334),df['PrecipitationSumInches']*25.4)
plt.show()

# %%
pf = df['PrecipitationSumInches']*25.4
list = []
for i in range(0,334):
    if pf.values[i] == 0:
        list.append(i)
print(len(list))
# Out:
# 231

# %%
nf = df.drop(list, axis=0)
nf
# Out:
#      TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0         74.0      60.0      45.0           67.0          49.0          43.0
# 4         58.0      50.0      41.0           44.0          40.0          36.0
# 6         60.0      53.0      45.0           41.0          39.0          37.0
# 7         62.0      51.0      40.0           43.0          39.0          33.0
# 18        53.0      47.0      40.0           51.0          45.0          30.0
# ..         ...       ...       ...            ...           ...           ...
# 318       75.0      67.0      58.0           69.0          63.0          57.0
# 319       59.0      57.0      55.0           58.0          56.0          54.0
# 320       63.0      59.0      55.0           56.0          51.0          46.0
# 329       48.0      44.0      40.0           47.0          39.0          23.0
# 330       50.0      42.0      34.0           49.0          45.0          28.0
#
# ...

# %%
plt.scatter(range(103),nf['TempHighF'])
plt.scatter(range(103),nf['PrecipitationSumInches']*25.4)
plt.show()
