# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('a.csv')
df['PrecipitationSumInches'] = df['PrecipitationSumInches'].multiply(25.4)

# %%
df
# Out:
#      TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0         74.0      60.0      45.0           67.0          49.0          43.0
# 1         56.0      48.0      39.0           43.0          36.0          28.0
# 2         58.0      45.0      32.0           31.0          27.0          23.0
# 3         61.0      46.0      31.0           36.0          28.0          21.0
# 4         58.0      50.0      41.0           44.0          40.0          36.0
# ..         ...       ...       ...            ...           ...           ...
# 329       48.0      44.0      40.0           47.0          39.0          23.0
# 330       50.0      42.0      34.0           49.0          45.0          28.0
# 331       53.0      42.0      30.0           27.0          21.0          14.0
# 332       56.0      43.0      30.0           27.0          23.0          19.0
# 333       69.0      51.0      33.0           45.0          38.0          23.0
#
# ...

# %%
df.values[0]
# Out:
# array([74.   , 60.   , 45.   , 67.   , 49.   , 43.   , 93.   , 75.   ,
#        57.   , 29.86 , 29.68 , 29.59 , 10.   ,  7.   ,  2.   , 20.   ,
#         4.   , 31.   , 11.684])

# %%
nf = df.drop(['TempHighF','TempLowF','DewPointHighF','DewPointLowF','HumidityHighPercent','HumidityLowPercent','SeaLevelPressureHighInches','SeaLevelPressureLowInches'], axis = 1)

# %%
nf
# Out:
#      TempAvgF  DewPointAvgF  HumidityAvgPercent  SeaLevelPressureAvgInches  \
# 0        60.0          49.0                75.0                      29.68
# 1        48.0          36.0                68.0                      30.13
# 2        45.0          27.0                52.0                      30.49
# 3        46.0          28.0                56.0                      30.45
# 4        50.0          40.0                71.0                      30.33
# ..        ...           ...                 ...                        ...
# 329      44.0          39.0                72.0                      30.14
# 330      42.0          45.0                91.0                      30.00
# 331      42.0          21.0                52.0                      30.40
# 332      43.0          23.0                51.0                      30.48
# 333      51.0          38.0                64.0                      30.27
#
# ...

# %%
#from sklearn.selection import train_test_split
from sklearn.linear_model import LinearRegression as LR

# %%
x = nf.drop(['PrecipitationSumInches'], axis=1)
y = nf['PrecipitationSumInches']
y.shape
# Out:
# (334,)

# %%
x = np.array(x)
x.reshape(-1,1)
x.shape
# Out:
# (334, 10)

# %%
x.shape
# Out:
# (334, 10)

# %%
y = y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (334, 1)

# %%
lr = LR()

# %%
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
ar = np.array([50.0,40.0,71.0,30.33,10.0,10.0,7.0,10.0,2.0,16.0])
ar  = ar.reshape(1,10)
print(ar)
# Out:
# [[50.   40.   71.   30.33 10.   10.    7.   10.    2.   16.  ]]

# %%
pre = lr.predict(ar)
print(pre)
# Out:
# [[1.49751909]]

# %%
ntp = pd.read_csv('needtopredict.csv')
ntp.shape
# Out:
# (29, 20)

# %%
ntp = ntp.drop(['TempHighF','TempLowF','DewPointHighF','DewPointLowF','HumidityHighPercent','HumidityLowPercent','SeaLevelPressureHighInches','SeaLevelPressureLowInches','PrecipitationSumInches','hrs'], axis = 1)

# %%
ntp.shape
# Out:
# (29, 10)

# %%
arr_ntp = np.array(ntp)
for i in range(0,29):
    print(ntp.values[i])
# Out:
# [68.   65.   90.   30.05 10.    6.    0.   13.    5.   20.  ]
# [63.   62.   97.   29.86 10.    6.    0.   20.    7.   28.  ]
# [67.   48.   62.   29.64 10.   10.   10.   16.    5.   27.  ]
# [53.   32.   47.   30.06 10.   10.   10.   15.    5.   28.  ]
# [53.   33.   53.   30.26 10.   10.   10.    9.    3.   16.  ]
# [60.   33.   40.   30.22 10.   10.   10.   10.    3.   17.  ]
# [53.   33.   52.   30.45 10.   10.   10.   10.    4.   16.  ]
# [57.   45.   62.   30.24 10.   10.   10.   14.    4.   24.  ]
# [65.   57.   75.   30.02 10.   10.   10.   16.    7.   31.  ]
# [72.   62.   71.   30.03 10.   10.   10.   15.    7.   28.  ]
# [54.   42.   69.   30.31 10.   10.    8.   17.    6.   30.  ]
# [45.   32.   63.   30.33 10.   10.   10.   10.    4.   16.  ]
# [54.   50.   88.   30.18 10.    7.    2.    7.    1.   10.  ]
# [62.   61.   94.   30.11 10.    3.    1.   12.    3.   16.  ]
# [69.   64.   82.   30.08 10.    8.    2.   12.    5.   20.  ]
# ...

# %%
pre_list = []
for i in range(0,29):
    pre_list.append(lr.predict(arr_ntp[i].reshape(-1,1).transpose())[0])
print(pre_list)
# Out:
# [array([11.41760202]), array([17.25765807]), array([1.22444785]), array([-1.44526834]), array([-4.30964294]), array([-4.20450271]), array([-3.5487269]), array([1.5292728]), array([0.99900954]), array([0.28436616]), array([3.73499428]), array([-3.07490273]), array([6.45035328]), array([15.7367022]), array([6.51343608]), array([0.5960977]), array([-1.04721903]), array([-0.75395861]), array([5.27219692]), array([2.92819099]), array([4.13641561]), array([1.49051424]), array([6.15245328]), array([4.16860639]), array([-0.44024554]), array([-0.54660128]), array([9.56872872]), array([13.58930156]), array([6.9251542])]

# %%
list=[]
for i in range(0,29):
    #if pre_list[i][0] <= 0.0
    list.append(pre_list[i][0])
pdf = pd.DataFrame({'pre':list})

# %%
pdf
# Out:
#           pre
# 0   11.417602
# 1   17.257658
# 2    1.224448
# 3   -1.445268
# 4   -4.309643
# 5   -4.204503
# 6   -3.548727
# 7    1.529273
# 8    0.999010
# 9    0.284366
# 10   3.734994
# 11  -3.074903
# 12   6.450353
# 13  15.736702
# 14   6.513436
# 15   0.596098
# 16  -1.047219
# 17  -0.753959
# 18   5.272197
# 19   2.928191
# 20   4.136416
# 21   1.490514
# 22   6.152453
# 23   4.168606
# 24  -0.440246
# 25  -0.546601
# 26   9.568729
# 27  13.589302
# 28   6.925154

# %%
t=0
final_prediction = []
for i in range(0,29):
    if pdf.values[i][0]<=0:
        final_prediction.append(0)
    else:
        final_prediction.append(pdf.values[i][0])
    t = pdf.values[i][0] + t
print(t)
# Out:
# 100.60443381306222

# %%
unpredicted = pd.read_csv('pre.csv')

# %%
unpredicteddf = unpredicted['PrecipitationSumInches']
unpredicteddf
# Out:
# 0                 0.46
# 1                    0
# 2                    0
# 3                    0
# 4                    T
#             ...
# 359    Need to predict
# 360    Need to predict
# 361    Need to predict
# 362    Need to predict
# 363    Need to predict
# Name: PrecipitationSumInches, Length: 364, dtype: object

# %%
npcsvdf = pd.read_csv('needtopredict.csv')
npcsvdf = npcsvdf.drop(['PrecipitationSumInches','hrs'], axis = 1)
npcsvdf
# Out:
#     TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0          74        68        62             69            65            62
# 1          67        63        58             64            62            56
# 2          81        67        53             57            48            39
# 3          66        53        40             39            32            19
# 4          67        53        38             38            33            25
# 5          77        60        42             37            33            27
# 6          64        53        42             37            33            27
# 7          72        57        42             54            45            35
# 8          73        65        56             61            57            52
# 9          79        72        64             63            62            59
# 10         66        54        41             63            42            22
# ...

# %%
npcsvdf['PrecipitationSumMm'] = final_prediction

# %%
npcsvdf
# Out:
#     TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0          74        68        62             69            65            62
# 1          67        63        58             64            62            56
# 2          81        67        53             57            48            39
# 3          66        53        40             39            32            19
# 4          67        53        38             38            33            25
# 5          77        60        42             37            33            27
# 6          64        53        42             37            33            27
# 7          72        57        42             54            45            35
# 8          73        65        56             61            57            52
# 9          79        72        64             63            62            59
# 10         66        54        41             63            42            22
# ...

# %%
df = df.rename(columns = {'PrecipitationSumInches':'PrecipitationSumMm'})

# %%
final_df = pd.concat([df, npcsvdf])

# %%
final_df
# Out:
#     TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0        74.0      60.0      45.0           67.0          49.0          43.0
# 1        56.0      48.0      39.0           43.0          36.0          28.0
# 2        58.0      45.0      32.0           31.0          27.0          23.0
# 3        61.0      46.0      31.0           36.0          28.0          21.0
# 4        58.0      50.0      41.0           44.0          40.0          36.0
# ..        ...       ...       ...            ...           ...           ...
# 24       74.0      63.0      52.0           64.0          51.0          32.0
# 25       63.0      55.0      46.0           36.0          34.0          32.0
# 26       53.0      51.0      48.0           51.0          44.0          35.0
# 27       60.0      55.0      49.0           56.0          51.0          48.0
# 28       57.0      53.0      48.0           50.0          48.0          44.0
#
# ...

# %%
final_df.to_csv('FINAL.csv', index = False)
